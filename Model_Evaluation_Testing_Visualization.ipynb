# %%
import matplotlib
import matplotlib.pyplot as plt
import json
import pickle
import numpy as np
import nltk
# nltk.download('punkt')

# from evaluate import bleu, cider, meteor, rouge, spice
from pycocoevalcap.bleu.bleu import Bleu
from pycocoevalcap.cider.cider import Cider
from pycocoevalcap.rouge.rouge import Rouge

#from sample import get_sentence

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from sample import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load results 
loss_val = np.load('result/loss_val_noAttnVer2.npy')
loss_train = np.load('result/loss_train_noAttnVer2.npy')

# from iterations to epochs (10 epochs):
loss_val_per_epoch = np.mean(loss_val.reshape(10, len(loss_val)//10), axis=1)
loss_train_per_epoch = np.mean(loss_train.reshape(10, len(loss_train)//10)[:, -10:], axis=1)

# %%
# plot training loss vs iterations:
plt.plot(range(len(loss_train)), loss_train)
plt.grid()
plt.ylabel('Crossentropy loss')
plt.xlabel('Iteration')
plt.title('Loss vs iterations')
# Out:
# Text(0.5, 1.0, 'Loss vs iterations')

# %%
#plot validation loss vs iterations:
plt.plot(range(len(loss_val)), loss_val)
plt.grid()
plt.ylabel('Crossentropy loss')
plt.xlabel('Iteration')
plt.title('Loss vs iterations')
# Out:
# Text(0.5, 1.0, 'Loss vs iterations')

# %%
# plot average train and validation loss per epoch 
plt.plot(range(1, len(loss_val_per_epoch)+1), loss_val_per_epoch)
plt.plot(range(1, len(loss_train_per_epoch)+1), loss_train_per_epoch)
plt.grid()
plt.legend(['Validation Loss', 'Train Loss'])
plt.ylabel('Crossentropy loss')
plt.xlabel('Epoch')
plt.title('Crossentropy Loss vs iterations')
# Out:
# Text(0.5, 1.0, 'Crossentropy Loss vs iterations')

# %%
# loss_val = np.load('output/loss_val1.npy')
# loss_train = np.load('output/loss_train1.npy')


# loss_val_per_epoch = np.mean(loss_val.reshape(10, len(loss_val)//10), axis=1)
# loss_train_per_epoch = np.mean(loss_train.reshape(10, len(loss_train)//10)[:, -10:], axis=1)


# with open('output/results1.json', 'r') as f:
#     results = json.load(f)
loss_val = np.load('result/loss_val_AttnVer1.npy')
loss_train = np.load('result/loss_train_AttnVer1.npy')


loss_val_per_epoch = np.mean(loss_val.reshape(10, len(loss_val)//10), axis=1)
loss_train_per_epoch = np.mean(loss_train.reshape(10, len(loss_train)//10)[:, -10:], axis=1)


with open('result/results_AttnVer1.json', 'r') as f:
    results = json.load(f)

# %%
# plot training loss vs iterations:
plt.plot(range(len(loss_train)), loss_train)
plt.grid()
plt.ylabel('Crossentropy loss')
plt.xlabel('Iteration')
plt.title('Loss vs iterations')
# Out:
# Text(0.5, 1.0, 'Loss vs iterations')

# %%
#plot validation loss vs iterations:
plt.plot(range(len(loss_val)), loss_val)
plt.grid()
plt.ylabel('Crossentropy loss')
plt.xlabel('Iteration')
plt.title('Loss vs iterations')
# Out:
# Text(0.5, 1.0, 'Loss vs iterations')

# %%
plt.plot(range(1, len(loss_val_per_epoch)+1), loss_val_per_epoch)
plt.plot(range(1, len(loss_val_per_epoch)+1), loss_train_per_epoch)
plt.grid()
plt.legend(['Validation Loss', 'Train Loss'])
plt.ylabel('Crossentropy loss')
plt.xlabel('Epoch')
plt.title('Crossentropy Loss vs iterations')
# Out:
# Text(0.5, 1.0, 'Crossentropy Loss vs iterations')

# %% [markdown]
# ## Images Taken by Ourselves

# %%
img = mpimg.imread('./data/test/VizWiz_test_1.jpg')
imgplot = plt.imshow(img)
plt.show()

# %run sample.py --image 'VizWiz_test_1.jpg' --image_path 'data/test' --encoder_path './models_test/noAtten/ver2/encoder_noAttnVer2_10.ckpt'\
    --decoder_path './models_test/noAtten/ver2/decoder_noAttnVer2_10.ckpt' --vocab_path 'data/vocab.pkl' --num_layers 2 --model_type 'no_attention' 

# %run sample.py --image 'VizWiz_test_1.jpg' --image_path 'data/test' --encoder_path './models_test/Atten/encoder_AttnVer1_10.ckpt'\
    --decoder_path './models_test/Atten/decoder_AttnVer1_10.ckpt' --vocab_path 'data/vocab.pkl' --num_layers 2 --model_type 'attention'
# Out:
# This is the result from CNN-LSTM without Attention:
# <start> <start> a box of <unk> <unk> <unk> sits on a persons lap . <end>
#
#
# This is the result from CNN-LSTM with Attention:
# <start> a person is holding a bottle of wine in their lap . <end>

# %%
img = mpimg.imread('./data/test/VizWiz_test_2.jpg')
imgplot = plt.imshow(img)
plt.show()

# %run sample.py --image 'VizWiz_test_2.jpg' --image_path 'data/test' --encoder_path './models_test/noAtten/ver2/encoder_noAttnVer2_10.ckpt'\
    --decoder_path './models_test/noAtten/ver2/decoder_noAttnVer2_10.ckpt' --vocab_path 'data/vocab.pkl' --num_layers 2 --model_type 'no_attention' 

# %run sample.py --image 'VizWiz_test_2.jpg' --image_path 'data/test' --encoder_path './models_test/Atten/encoder_AttnVer1_10.ckpt'\
    --decoder_path './models_test/Atten/decoder_AttnVer1_10.ckpt' --vocab_path 'data/vocab.pkl' --num_layers 2 --model_type 'attention'
# Out:
# This is the result from CNN-LSTM without Attention:
# <start> <start> a box of food is on a table with a person standing over it . <end>
#
#
# This is the result from CNN-LSTM with Attention:
# <start> a box of food is on a table . <end>

# %% [markdown]
# ## Images from Test Set

# %%
img = mpimg.imread('./data/test/VizWiz_test_00000001.jpg')
imgplot = plt.imshow(img)
plt.show()

# %run sample.py --image 'VizWiz_test_00000001.jpg' --image_path 'data/test' --encoder_path './models_test/noAtten/ver2/encoder_noAttnVer2_10.ckpt'\
    --decoder_path './models_test/noAtten/ver2/decoder_noAttnVer2_10.ckpt' --vocab_path 'data/vocab.pkl' --num_layers 2 --model_type 'no_attention' 

# %run sample.py --image 'VizWiz_test_00000001.jpg' --image_path 'data/test' --encoder_path './models_test/Atten/encoder_AttnVer1_10.ckpt'\
    --decoder_path './models_test/Atten/decoder_AttnVer1_10.ckpt' --vocab_path 'data/vocab.pkl' --num_layers 2 --model_type 'attention'
# Out:
# This is the result from CNN-LSTM without Attention:
# <start> <start> quality issues are too severe to recognize visual content . <end>
#
#
# This is the result from CNN-LSTM with Attention:
# <start> a white box with a barcode on the back <end>

# %%
img = mpimg.imread('./data/test/VizWiz_test_00000002.jpg')
imgplot = plt.imshow(img)
plt.show()

# %run sample.py --image 'VizWiz_test_00000002.jpg' --image_path 'data/test' --encoder_path './models_test/noAtten/ver2/encoder_noAttnVer2_10.ckpt'\
    --decoder_path './models_test/noAtten/ver2/decoder_noAttnVer2_10.ckpt' --vocab_path 'data/vocab.pkl' --num_layers 2 --model_type 'no_attention' 

# %run sample.py --image 'VizWiz_test_00000002.jpg' --image_path 'data/test' --encoder_path './models_test/Atten/encoder_AttnVer1_10.ckpt'\
    --decoder_path './models_test/Atten/decoder_AttnVer1_10.ckpt' --vocab_path 'data/vocab.pkl' --num_layers 2 --model_type 'attention'
# Out:
# This is the result from CNN-LSTM without Attention:
# <start> <start> a white thermostat with a digital display on the front and a dial for the temperature . <end>
#
#
# This is the result from CNN-LSTM with Attention:
# <start> a white and gray striped shirt with a black logo . <end>

# %% [markdown]
# ## Images from Validation Set

# %%
img = mpimg.imread('./data/val/VizWiz_val_00000001.jpg')
imgplot = plt.imshow(img)
plt.show()

# %run sample.py --image 'VizWiz_val_00000001.jpg' --image_path 'data/val' --encoder_path './models_test/noAtten/ver2/encoder_noAttnVer2_10.ckpt'\
--decoder_path './models_test/noAtten/ver2/decoder_noAttnVer2_10.ckpt' --vocab_path 'data/vocab.pkl' --num_layers 2 --model_type 'no_attention' 

# %run sample.py --image 'VizWiz_val_00000001.jpg' --image_path 'data/val' --encoder_path './models_test/Atten/encoder_AttnVer1_10.ckpt'\
    --decoder_path './models_test/Atten/decoder_AttnVer1_10.ckpt' --vocab_path 'data/vocab.pkl' --num_layers 2 --model_type 'attention'
# Out:
# This is the result from CNN-LSTM without Attention:
# <start> <start> a bottle of <unk> <unk> <unk> <unk> <unk> <unk> . <end>
#
#
# This is the result from CNN-LSTM with Attention:
# <start> a can of campbell 's soup on a counter top <end>

# %%
img = mpimg.imread('./data/val/VizWiz_val_00000005.jpg')
imgplot = plt.imshow(img)
plt.show()

# %run sample.py --model_type 'no_attention' --image 'VizWiz_val_00000005.jpg' --image_path 'data/val' --encoder_path './models_test/noAtten/ver2/encoder_noAttnVer2_10.ckpt'\
--decoder_path './models_test/noAtten/ver2/decoder_noAttnVer2_10.ckpt' 

# %run sample.py --model_type 'attention' --image 'VizWiz_val_00000005.jpg' --image_path 'data/val' --encoder_path './models_test/Atten/encoder_AttnVer1_10.ckpt'\
--decoder_path './models_test/Atten/decoder_AttnVer1_10.ckpt'
# Out:
# This is the result from CNN-LSTM without Attention:
# <start> <start> a computer screen with a captcha on it . <end>
#
#
# This is the result from CNN-LSTM with Attention:
# <start> a computer screen with a blue background and a white loading message <end>
